# %% [markdown]
# # **Computer Science and Engineering Department**
# #**Artificial Intelligence (UCS 521)**
# # Project: **Automatic Answer Sheet Evaluation System**
#
# ---
#
#
#
# Authors:
#
#     SAMARTH MAHAJAN - 102303717
#     MADHAV KAPILA - 102303721
#     SNEHA GOSWAMI - 102303723
#
# ---

# %% [markdown]
# # Google Drive Connecting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/'
# /content

# %% [markdown]
# # Resolving PATHS

# %%
PATHS = {
    # Core datasets
    'questions': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/QuestionAnswersDataSet.csv',
    'keywords': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Keywords.csv',
    'weights': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Evaluation_Weightage.csv',

    # Output files
    'output': {
        'results': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/results.csv',
        'metadata': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/result_metadata.csv'
    },

    # PDF input
    'data': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/Test/test_perfect.pdf'
}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System

# %% [markdown]
# # pdf_preprocessor.py
#
# Used to extract full text out of the pdf starting from a given page

# %%
# pdf_Preprocessor.py

import fitz
class PDFProcessor:
    def __init__(self, start_page=1):
        self.start_page = start_page - 1  # 0-based index
        logging.getLogger("pdfminer").setLevel(logging.ERROR)

    def extract_text(self, pdf_path):
        doc = fitz.open(pdf_path)
        full_text = ""
        for page_num in range(self.start_page, len(doc)):
            full_text += doc[page_num].get_text()
        return full_text

# %% [markdown]
# # answer_parser.py
#
# Used to separate Question headings and answer content from preprocessed text using **pdf_plumber** library and **regex**(regular expression)

# %%
# answer_parser.py

import pdfplumber
import re

class AnswerParser:
    def __init__(self):
        # Comprehensive question pattern
        self.question_pattern = re.compile(
            r'(?:^|\n)(?:Q|Question|Problem|\d+)[\s.)-]*\s*(\d+)[\s:)-]*',
            re.IGNORECASE
        )

    def parse(self, pdf_path):
        """Parse PDF into {q_num: answer_text} using layout analysis"""
        answers = {}
        current_q = None
        answer_buffer = []

        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                # Extract text with layout preservation
                text = page.extract_text(layout=True, x_tolerance=5, y_tolerance=2)

                # Process text in order of appearance
                for line in text.split('\n'):
                    line = line.strip()
                    if not line:
                        continue

                    # Check for new question
                    match = self.question_pattern.search(line)
                    if match:
                        # Save previous answer
                        if current_q is not None:
                            answers[current_q] = ' '.join(answer_buffer).strip()
                            answer_buffer = []

                        current_q = int(match.group(1))
                        answer_start = match.end()
                        answer_buffer.append(line[answer_start:].strip())
                    else:
                        # Continue current answer
                        if current_q is not None:
                            answer_buffer.append(line)

        # Save last answer
        if current_q is not None:
            answers[current_q] = ' '.join(answer_buffer).strip()

        return self._merge_split_answers(answers)

    def _merge_split_answers(self, answers):
        """Merge answers split across pages/pages"""
        merged = {}
        sorted_qs = sorted(answers.keys())

        for q_num in sorted_qs:
            answer = answers[q_num]

            # Check if previous answer ends with continuation marker
            if q_num-1 in merged and merged[q_num-1].endswith((' ', '-')):
                merged[q_num-1] += ' ' + answer
            else:
                merged[q_num] = answer

        return merged

# %% [markdown]
# # scoring_engine.py
#
# The heart of the project where all code related to the model lies. Here we firstly load data according to our need and then score our answers based on three major categories weighted according to type of question
#
#
# 1.   *Semantic Similarity* : Analysis performed using **SentenceTransformer** library a new age semantic analysis libraries replacing old RNN/LSTM models
# 2.   *Keyword Matching* : Using **string manipulation** we find total no. of required keywords used in the answer by the student
# 3.   *Grammar Check* : Using **TextBlob** NLP library we check if the word we used in the answer is correctly matching to the grammatically correct word that should be used there as TextBlob gives correct word suggestions for every word it parses.

# %%
# scoring_engine.py

import os
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

class ScoringEngine:
    def __init__(self):
        #Initialize with paths from config
        self.weights = self._load_data('weights')
        self.keywords = self._load_data('keywords')
        self.teacher_answers = self._load_answers('questions')
        self.model = SentenceTransformer('all-MiniLM-L6-v2')

    def _load_data(self, path_key):
        path = PATHS[path_key]
        if not path or not os.path.exists(path):
            raise FileNotFoundError(f"Path not found: {path}")
        return pd.read_csv(path, encoding='latin1')

    def _load_answers(self, path_key):
        #Specialized answer loader with column renaming
        df = self._load_data(path_key)
        return df.rename(columns={'Question Number': 'Question_Number'})[['Question_Number', 'Answer']]#We are only interested in these two columns
        #Ensure the column names are consistent with the rest of the code

    def _get_weights(self, q_num):
        matches = self.weights[self.weights['question'] == q_num]
        if matches.empty:
            raise KeyError(f"No weights found for Q{q_num}")  # Changed to KeyError
        return matches.iloc[0]

    def _get_model_answer(self, q_num):
        matches = self.teacher_answers[self.teacher_answers['Question_Number'] == q_num]
        if matches.empty:
            raise KeyError(f"No model answer found for Q{q_num}")  # Changed to KeyError
        return matches['Answer'].values[0]

    # def _get_keywords(self, q_num):
    #     #Retrieve and clean keywords
    #     keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
    #     return [
    #         str(kw).strip().lower()
    #         for col in keywords.values
    #         for kw in col
    #         if pd.notna(kw) and str(kw).strip()
    #     ]

    def _get_keywords(self, q_num):
        keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
        return [
            ' '.join(str(kw).strip().lower().split())
            for col in keywords.values
            for kw in col
            if pd.notna(kw) and str(kw).strip()
        ]


    def calculate_grammar_score(self, text):
        #Calculate grammar score with error normalization
        if not text.strip():
            return 0.0

        blob = TextBlob(text)
        total_words = len(blob.words)
        if total_words == 0:
            return 0.0

        error_count = sum(
            1 for word in blob.words
            if word.spellcheck()[0][0].lower() != word.lower()
        )
        return 1 - (error_count / total_words)

    # def calculate_keyword_score(self, student_answer, q_num):
    #     #Calculate keyword match score
    #     target_keywords = self._get_keywords(q_num)
    #     if not target_keywords:
    #         return 0.0

    #     student_words = student_answer.lower().split()
    #     matches = sum(1 for kw in target_keywords if any(kw in word for word in student_words))
    #     return matches / len(target_keywords)

    def calculate_keyword_score(self, student_answer, q_num):
        target_keywords = self._get_keywords(q_num)
        if not target_keywords:
            return 0.0

        # Split student answer into words
        student_words = student_answer.lower().split()

        # Convert keywords to word sequences
        keyword_phrases = [kw.split() for kw in target_keywords]

        matches = 0
        for phrase in keyword_phrases:
            # Check for phrase using sliding window
            phrase_length = len(phrase)
            found = False
            for i in range(len(student_words) - phrase_length + 1):
                if student_words[i:i+phrase_length] == phrase:
                    found = True
                    break
            if found:
                matches += 1

        return matches / len(target_keywords)

    def calculate_semantic_score(self, student_answer, q_num):
        #Calculate semantic similarity score
        model_answer = self._get_model_answer(q_num)
        embeddings = self.model.encode([model_answer, student_answer])
        return cosine_similarity([embeddings[0]], [embeddings[1]])[0][0]

    def calculate_total_score(self, student_answer, q_num):
        weights = self._get_weights(q_num)

        # Already correct - weights are normalized to 0-1 scale

        g = self.calculate_grammar_score(student_answer) * (weights['grammarwt']/100)
        k = self.calculate_keyword_score(student_answer, q_num) * (weights['Keywordswt']/100)
        s = self.calculate_semantic_score(student_answer, q_num) * (weights['similarityWt']/100)


        print(f'Question no. {q_num}')
        print(f'Grammar Score is {g} out of {weights["grammarwt"]/100.0}')
        print(f'Keyword Score is {k} out of {weights["Keywordswt"]/100.0}')
        print(f'Semantic Score is {s} out of {weights["similarityWt"]/100.0}')

        return (g + k + s)

# %% [markdown]
# # result_generator.py
#
# It gets the marks scored by student and saves those marks into a csv named results.csv for future referencing

# %%
# result_generator.py

import pandas as pd


class ResultGenerator:
    def __init__(self):
        self.results_df = pd.DataFrame(columns=['RollNo', 'Name', 'Total', 'Percentage'])
        self.metadata_df = pd.DataFrame()

    def add_student(self, rollno, name, scores):
        # Add default 0 scores for missing questions
        for q_num in range(1, 201):
            if q_num not in scores:
                scores[q_num] = 0

        # Calculate total and percentage CORRECTLY
        max_possible = 200  # 200 questions
        total = sum(scores.values())
        perc = (total / max_possible) * 100  # Fixed here

        self.results_df.loc[len(self.results_df)] = [rollno, name, total, perc]

        # Update metadata
        student_data = {'RollNo': rollno, 'Name': name}
        student_data.update({'Total': total, 'Percentage': perc})

        self.metadata_df = pd.concat([self.metadata_df, pd.DataFrame([student_data])], ignore_index=True)

        return [rollno, name, total, perc]

    def save_results(self):
        self.results_df.to_csv(PATHS['output']['results'], mode='a', header=False, index=False)
        self.metadata_df.to_csv(PATHS['output']['metadata'], mode='a', header=False, index=False)

# %% [markdown]
# # main.py
#
# The central code of project which accepts all inputs, call all functions and handles all output

# %%
#Main.py

def evaluate_student(pdf_path, rollno, name, start_page=1):
    # Initialize components
    processor = PDFProcessor(start_page)
    parser = AnswerParser()
    scorer = ScoringEngine()
    reporter = ResultGenerator()

    # Process PDF
    raw_text = processor.extract_text(pdf_path)
    # clean_text = parser.preprocess_pdf_text(raw_text)  # Static method call
    answers = parser.parse(pdf_path)  # Instance method

    # Score answers
    scores = {}
    for q_num, answer_text in answers.items():  # Direct answer access
        try:
            scores[q_num] = scorer.calculate_total_score(answer_text, q_num)
        except KeyError as e:
            print(f"Skipping Q{q_num}: {str(e)}")

    # Generate reports
    ans = reporter.add_student(rollno, name, scores)
    reporter.save_results()
    print(f"Processed {ans[0]} {ans[1]}. Total: {ans[2]}.  Percentage: {ans[3]}%")

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %% [markdown]
# # Driver Code - cli.py
#
# The driver code of our project to use when running project using Command Line Interface

# %%
# Driver code - cli.py

def colab_evaluate_student():
    # Input parameters
    rollno = input("Enter Roll Number: ")
    name = input("Enter Student Name: ")
    start_page = int(input("Start page [1]: ") or 1)

    # try:
        # Verify PDF path
    pdf_path = PATHS['data']
    if not os.path.isfile(pdf_path):
      raise FileNotFoundError(f"PDF not found: {pdf_path}")

        # Process evaluation
    evaluate_student(pdf_path, rollno, name, start_page)
    print("\n✅ Evaluation Complete!")

    # except Exception as e:
        # print(f"\n❌ Error: {str(e)}")


colab_evaluate_student()
# Out:
# Enter Roll Number: 1
# Enter Student Name: A
# Start page [1]: 1
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# WARNING:pdfminer.pdfpage:CropBox missing from /Page, defaulting to MediaBox
# Processed 1 A. Total: 9667.643528009507.  Percentage: 4833.821764004753%
#
# ✅ Evaluation Complete!

# %% [markdown]
# # Test 1
# Using non-erronous pdf from all aspects

# %%
# !pip install pymupdf pdfplumber pandas numpy easyocr pdf2image nltk scikit-learn sentence-transformers flask reportlab textblob
# !pip install --upgrade pymupdf
import fitz
import pdfplumber
import re
import os
import logging
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
import os
import argparse
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/

PATHS = {
    # Core datasets
    'questions': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/QuestionAnswersDataSet.csv',
    'keywords': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Keywords.csv',
    'weights': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Evaluation_Weightage.csv',

    # Output files
    'output': {
        'results': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/results.csv',
        'metadata': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/result_metadata.csv'
    },

    # PDF input
    'data': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/Test/test_perfect.pdf'
}
import fitz
class PDFProcessor:
    def __init__(self, start_page=1):
        self.start_page = start_page - 1  # 0-based index
        logging.getLogger("pdfminer").setLevel(logging.ERROR)

    def extract_text(self, pdf_path):
        doc = fitz.open(pdf_path)
        full_text = ""
        for page_num in range(self.start_page, len(doc)):
            full_text += doc[page_num].get_text()
        return full_text


import pdfplumber
import re

class AnswerParser:
    def __init__(self):
        # Comprehensive question pattern
        self.question_pattern = re.compile(
            r'(?:^|\n)(?:Q|Question|Problem|\d+)[\s.)-]*\s*(\d+)[\s:)-]*',
            re.IGNORECASE
        )

    def parse(self, pdf_path):
        """Parse PDF into {q_num: answer_text} using layout analysis"""
        answers = {}
        current_q = None
        answer_buffer = []

        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                # Extract text with layout preservation
                text = page.extract_text(layout=True, x_tolerance=5, y_tolerance=2)

                # Process text in order of appearance
                for line in text.split('\n'):
                    line = line.strip()
                    if not line:
                        continue

                    # Check for new question
                    match = self.question_pattern.search(line)
                    if match:
                        # Save previous answer
                        if current_q is not None:
                            answers[current_q] = ' '.join(answer_buffer).strip()
                            answer_buffer = []

                        current_q = int(match.group(1))
                        answer_start = match.end()
                        answer_buffer.append(line[answer_start:].strip())
                    else:
                        # Continue current answer
                        if current_q is not None:
                            answer_buffer.append(line)

        # Save last answer
        if current_q is not None:
            answers[current_q] = ' '.join(answer_buffer).strip()

        return self._merge_split_answers(answers)

    def _merge_split_answers(self, answers):
        """Merge answers split across pages/pages"""
        merged = {}
        sorted_qs = sorted(answers.keys())

        for q_num in sorted_qs:
            answer = answers[q_num]

            # Check if previous answer ends with continuation marker
            if q_num-1 in merged and merged[q_num-1].endswith((' ', '-')):
                merged[q_num-1] += ' ' + answer
            else:
                merged[q_num] = answer

        return merged

import os
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

class ScoringEngine:
    def __init__(self):
        #Initialize with paths from config
        self.weights = self._load_data('weights')
        self.keywords = self._load_data('keywords')
        self.teacher_answers = self._load_answers('questions')
        self.model = SentenceTransformer('all-MiniLM-L6-v2')

    def _load_data(self, path_key):
        path = PATHS[path_key]
        if not path or not os.path.exists(path):
            raise FileNotFoundError(f"Path not found: {path}")
        return pd.read_csv(path, encoding='latin1')

    def _load_answers(self, path_key):
        #Specialized answer loader with column renaming
        df = self._load_data(path_key)
        return df.rename(columns={'Question Number': 'Question_Number'})[['Question_Number', 'Answer']]#We are only interested in these two columns
        #Ensure the column names are consistent with the rest of the code

    def _get_weights(self, q_num):
        matches = self.weights[self.weights['question'] == q_num]
        if matches.empty:
            raise KeyError(f"No weights found for Q{q_num}")  # Changed to KeyError
        return matches.iloc[0]

    def _get_model_answer(self, q_num):
        matches = self.teacher_answers[self.teacher_answers['Question_Number'] == q_num]
        if matches.empty:
            raise KeyError(f"No model answer found for Q{q_num}")  # Changed to KeyError
        return matches['Answer'].values[0]

    # def _get_keywords(self, q_num):
    #     #Retrieve and clean keywords
    #     keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
    #     return [
    #         str(kw).strip().lower()
    #         for col in keywords.values
    #         for kw in col
    #         if pd.notna(kw) and str(kw).strip()
    #     ]

    def _get_keywords(self, q_num):
        keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
        return [
            ' '.join(str(kw).strip().lower().split())
            for col in keywords.values
            for kw in col
            if pd.notna(kw) and str(kw).strip()
        ]


    def calculate_grammar_score(self, text):
        #Calculate grammar score with error normalization
        if not text.strip():
            return 0.0

        blob = TextBlob(text)
        total_words = len(blob.words)
        if total_words == 0:
            return 0.0

        error_count = sum(
            1 for word in blob.words
            if word.spellcheck()[0][0].lower() != word.lower()
        )
        return 1 - (error_count / total_words)

    # def calculate_keyword_score(self, student_answer, q_num):
    #     #Calculate keyword match score
    #     target_keywords = self._get_keywords(q_num)
    #     if not target_keywords:
    #         return 0.0

    #     student_words = student_answer.lower().split()
    #     matches = sum(1 for kw in target_keywords if any(kw in word for word in student_words))
    #     return matches / len(target_keywords)

    def calculate_keyword_score(self, student_answer, q_num):
        target_keywords = self._get_keywords(q_num)
        if not target_keywords:
            return 0.0

        # Split student answer into words
        student_words = student_answer.lower().split()

        # Convert keywords to word sequences
        keyword_phrases = [kw.split() for kw in target_keywords]

        matches = 0
        for phrase in keyword_phrases:
            # Check for phrase using sliding window
            phrase_length = len(phrase)
            found = False
            for i in range(len(student_words) - phrase_length + 1):
                if student_words[i:i+phrase_length] == phrase:
                    found = True
                    break
            if found:
                matches += 1

        return matches / len(target_keywords)

    def calculate_semantic_score(self, student_answer, q_num):
        #Calculate semantic similarity score
        model_answer = self._get_model_answer(q_num)
        embeddings = self.model.encode([model_answer, student_answer])
        return cosine_similarity([embeddings[0]], [embeddings[1]])[0][0]

    def calculate_total_score(self, student_answer, q_num):
        weights = self._get_weights(q_num)

        # Already correct - weights are normalized to 0-1 scale

        g = self.calculate_grammar_score(student_answer) * (weights['grammarwt']/100)
        k = self.calculate_keyword_score(student_answer, q_num) * (weights['Keywordswt']/100)
        s = self.calculate_semantic_score(student_answer, q_num) * (weights['similarityWt']/100)


        print(f'Question no. {q_num}')
        print(f'Grammar Score is {g} out of {weights["grammarwt"]/100.0}')
        print(f'Keyword Score is {k} out of {weights["Keywordswt"]/100.0}')
        print(f'Semantic Score is {s} out of {weights["similarityWt"]/100.0}')

        return (g + k + s)

import pandas as pd


class ResultGenerator:
    def __init__(self):
        self.results_df = pd.DataFrame(columns=['RollNo', 'Name', 'Total', 'Percentage'])
        self.metadata_df = pd.DataFrame()

    def add_student(self, rollno, name, scores):
        # Add default 0 scores for missing questions
        for q_num in range(1, 201):
            if q_num not in scores:
                scores[q_num] = 0

        # Calculate total and percentage CORRECTLY
        max_possible = 200  # 200 questions
        total = sum(scores.values())
        perc = (total / max_possible) * 100  # Fixed here

        self.results_df.loc[len(self.results_df)] = [rollno, name, total, perc]

        # Update metadata
        student_data = {'RollNo': rollno, 'Name': name}
        student_data.update({'Total': total, 'Percentage': perc})

        self.metadata_df = pd.concat([self.metadata_df, pd.DataFrame([student_data])], ignore_index=True)

        return [rollno, name, total, perc]

    def save_results(self):
        self.results_df.to_csv(PATHS['output']['results'], mode='a', header=False, index=False)
        self.metadata_df.to_csv(PATHS['output']['metadata'], mode='a', header=False, index=False)


#Main.py

logging.getLogger("pdfminer").setLevel(logging.ERROR)

def evaluate_student(pdf_path, rollno, name, start_page=1):
    # Initialize components
    processor = PDFProcessor(start_page)
    parser = AnswerParser()
    scorer = ScoringEngine()
    reporter = ResultGenerator()

    # Process PDF
    raw_text = processor.extract_text(pdf_path)
    # clean_text = parser.preprocess_pdf_text(raw_text)  # Static method call
    answers = parser.parse(pdf_path)  # Instance method

    # Score answers with detailed logging
    scores = {}
    for q_num, answer_text in answers.items():
        try:
            # answer_text = answer_data['answer']
            score = scorer.calculate_total_score(answer_text, q_num)
            print(f"Q{q_num}: {score:.2f}/1.0")  # Print individual scores
            scores[q_num] = score
        except KeyError as e:
            print(f"\n⚠️ Skipping Q{q_num}: {str(e)}")
        except Exception as e:
            print(f"\n❌ Error processing Q{q_num}: {str(e)}")

    # Generate reports
    reporter.add_student(rollno, name, scores)
    reporter.save_results()
    total = sum(scores.values())
    max_score = len(answers)
    print(f"\nProcessed {name} ({rollno}). Total: {total}/{max_score} ({total/max_score*100:.2f}%)")



def colab_evaluate_student():
    # Input parameters
    rollno = input("Enter Roll Number: ")
    name = input("Enter Student Name: ")
    start_page = int(input("Start page [1]: ") or 1)

    # try:
        # Verify PDF path
    pdf_path = PATHS['data']
    if not os.path.isfile(pdf_path):
      raise FileNotFoundError(f"PDF not found: {pdf_path}")

        # Process evaluation
    evaluate_student(pdf_path, rollno, name, start_page)
    print("\n✅ Evaluation Complete!")

    # except Exception as e:
        # print(f"\n❌ Error: {str(e)}")


colab_evaluate_student()
# Out:
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.11/dist-packages (1.25.5)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.11/dist-packages (0.11.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: easyocr in /usr/local/lib/python3.11/dist-packages (1.7.2)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.11/dist-packages (1.17.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (3.1.0)
# Requirement already satisfied: reportlab in /usr/local/lib/python3.11/dist-packages (4.4.0)
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: pdfminer.six==20250327 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (20250327)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250327->pdfplumber) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250327->pdfplumber) (43.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from easyocr) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.11/dist-packages (from easyocr) (0.21.0+cu124)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from easyocr) (4.11.0.86)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from easyocr) (1.15.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.11/dist-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.11/dist-packages (from easyocr) (2.1.0)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.11/dist-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from easyocr) (1.11.1.4)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from reportlab) (5.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->easyocr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->easyocr) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber) (1.17.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber) (2.22)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.11/dist-packages (1.25.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System
# Enter Roll Number: 5
# Enter Student Name: E
# Start page [1]: 1
# Question no. 1
# Grammar Score is 0.07727272727272727 out of 0.1
# Keyword Score is 0.4 out of 0.4
# Semantic Score is 0.5000000596046448 out of 0.5
# Q1: 0.98/1.0
# Question no. 2
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q2: 1.00/1.0
# Question no. 3
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q3: 0.83/1.0
# Question no. 4
# Grammar Score is 0.16363636363636364 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q4: 0.71/1.0
# Question no. 5
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q5: 0.58/1.0
# Question no. 6
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q6: 0.88/1.0
# Question no. 7
# Grammar Score is 0.15200000000000002 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
#
out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q44: 0.62/1.0
# Question no. 45
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q45: 0.80/1.0
# Question no. 46
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q46: 0.99/1.0
# Question no. 47
# Grammar Score is 0.17894736842105263 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q47: 0.98/1.0
# Question no. 48
# Grammar Score is 0.18260869565217394 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q48: 0.98/1.0
# Question no. 49
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q49: 0.64/1.0
# Question no. 50
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q50: 0.82/1.0
# Question no. 51
# Grammar Score is 0.08461538461538462 out of 0.1
# Keyword Score is 0.2 out of 0.4
# Semantic Score is 0.4999999701976776 out of 0.5
# Q51: 0.78/1.0
# Question no. 52
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q52: 0.75/1.0
# Question no. 53
# Grammar Score is 0.08000000000000002 out of 0.1
# Keyword Score is 0.26666666666666666 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q53: 0.85/1.0
# Question no. 54
# Grammar Score is 0.09166666666666667 out of 0.1
# Keyword Score is 0.06666666666666667 out of 0.4
# Semantic Score is 0.5000000596046448 out of 0.5
# Q54: 0.66/1.0
# Question no. 55
# Grammar Score is 0.08333333333333334 out of 0.1
# Keyword Score is 0.26666666666666666 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q55: 0.85/1.0
# Question no. 56
# Grammar Score is 0.08000000000000002 out of 0.1
# Keyword Score is 0.26666666666666666 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q56: 0.85/1.0
# Question no. 57
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q57: 0.73/1.0
# Question no. 58
# Grammar Score is 0.15714285714285714 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q58: 0.96/1.0
# Question no. 59
# Grammar Score is 0.17391304347826086 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q59: 0.64/1.0
# Question no. 60
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q60: 0.65/1.0
# Question no. 61
# Grammar Score is 0.16842105263157894 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q61: 0.97/1.0
# Question no. 62
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q62: 0.45/1.0
# Question no. 63
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q63: 0.98/1.0
# Question no. 64
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q64: 0.98/1.0
# Question no. 65
# Grammar Score is 0.19 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q65: 0.99/1.0
# Question no. 66
# Grammar Score is 0.1 out of 0.1
# Keyword Score is 0.13333333333333333 out of 0.4
# Semantic Score is 0.5000000596046448 out of 0.5
# Q66: 0.73/1.0
# Question no. 67
# Grammar Score is 0.09230769230769231 out of 0.1
# Keyword Score is 0.33333333333333337 out of 0.4
# Semantic Score is 0.4999999403953552 out of 0.5
# Q67: 0.93/1.0
# Question no. 68
# Grammar Score is 0.1625 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q68: 0.80/1.0
# Question no. 69
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q69: 0.65/1.0
# Question no. 70
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29999994635581967 out of 0.3
# Q70: 0.64/1.0
# Question no. 71
# Grammar Score is 0.18947368421052635 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q71: 0.74/1.0
# Question no. 72
# Grammar Score is 0.1375 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q72: 0.85/1.0
# Question no. 73
# Grammar Score is 0.16470588235294117 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.3 out of 0.3
#
out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q185: 0.45/1.0
# Question no. 186
# Grammar Score is 0.09166666666666667 out of 0.1
# Keyword Score is 0.06666666666666667 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q186: 0.66/1.0
# Question no. 187
# Grammar Score is 0.15384615384615385 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q187: 0.54/1.0
# Question no. 188
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q188: 0.63/1.0
# Question no. 189
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q189: 1.00/1.0
# Question no. 190
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q190: 0.57/1.0
# Question no. 191
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q191: 0.47/1.0
# Question no. 192
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q192: 0.79/1.0
# Question no. 193
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q193: 0.55/1.0
# Question no. 194
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q194: 0.67/1.0
# Question no. 195
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q195: 0.63/1.0
# Question no. 196
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q196: 0.48/1.0
# Question no. 197
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q197: 0.75/1.0
# Question no. 198
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q198: 0.53/1.0
# Question no. 199
# Grammar Score is 0.16363636363636364 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q199: 0.55/1.0
# Question no. 200
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q200: 0.55/1.0
#
# Processed E (5). Total: 154.69310194676163/200 (77.35%)
#
# ✅ Evaluation Complete!

# %% [markdown]
# # Test 2
#
# Using pdf that is same as the previous one with no errors generated to text but having large extra_spaces

# %%
# !pip install pymupdf pdfplumber pandas numpy easyocr pdf2image nltk scikit-learn sentence-transformers flask reportlab textblob
# !pip install --upgrade pymupdf
import fitz
import pdfplumber
import re
import os
import logging
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
import os
import argparse
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/

PATHS = {
    # Core datasets
    'questions': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/QuestionAnswersDataSet.csv',
    'keywords': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Keywords.csv',
    'weights': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Evaluation_Weightage.csv',

    # Output files
    'output': {
        'results': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/results.csv',
        'metadata': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/result_metadata.csv'
    },

    # PDF input
    'data': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/Test/test_perfect_refined.pdf'
}
import fitz
class PDFProcessor:
    def __init__(self, start_page=1):
        self.start_page = start_page - 1  # 0-based index
        logging.getLogger("pdfminer").setLevel(logging.ERROR)

    def extract_text(self, pdf_path):
        doc = fitz.open(pdf_path)
        full_text = ""
        for page_num in range(self.start_page, len(doc)):
            full_text += doc[page_num].get_text()
        return full_text


import pdfplumber
import re

class AnswerParser:
    def __init__(self):
        # Comprehensive question pattern
        self.question_pattern = re.compile(
            r'(?:^|\n)(?:Q|Question|Problem|\d+)[\s.)-]*\s*(\d+)[\s:)-]*',
            re.IGNORECASE
        )

    def parse(self, pdf_path):
        """Parse PDF into {q_num: answer_text} using layout analysis"""
        answers = {}
        current_q = None
        answer_buffer = []

        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                # Extract text with layout preservation
                text = page.extract_text(layout=True, x_tolerance=5, y_tolerance=2)

                # Process text in order of appearance
                for line in text.split('\n'):
                    line = line.strip()
                    if not line:
                        continue

                    # Check for new question
                    match = self.question_pattern.search(line)
                    if match:
                        # Save previous answer
                        if current_q is not None:
                            answers[current_q] = ' '.join(answer_buffer).strip()
                            answer_buffer = []

                        current_q = int(match.group(1))
                        answer_start = match.end()
                        answer_buffer.append(line[answer_start:].strip())
                    else:
                        # Continue current answer
                        if current_q is not None:
                            answer_buffer.append(line)

        # Save last answer
        if current_q is not None:
            answers[current_q] = ' '.join(answer_buffer).strip()

        return self._merge_split_answers(answers)

    def _merge_split_answers(self, answers):
        """Merge answers split across pages/pages"""
        merged = {}
        sorted_qs = sorted(answers.keys())

        for q_num in sorted_qs:
            answer = answers[q_num]

            # Check if previous answer ends with continuation marker
            if q_num-1 in merged and merged[q_num-1].endswith((' ', '-')):
                merged[q_num-1] += ' ' + answer
            else:
                merged[q_num] = answer

        return merged

import os
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

class ScoringEngine:
    def __init__(self):
        #Initialize with paths from config
        self.weights = self._load_data('weights')
        self.keywords = self._load_data('keywords')
        self.teacher_answers = self._load_answers('questions')
        self.model = SentenceTransformer('all-MiniLM-L6-v2')

    def _load_data(self, path_key):
        path = PATHS[path_key]
        if not path or not os.path.exists(path):
            raise FileNotFoundError(f"Path not found: {path}")
        return pd.read_csv(path, encoding='latin1')

    def _load_answers(self, path_key):
        #Specialized answer loader with column renaming
        df = self._load_data(path_key)
        return df.rename(columns={'Question Number': 'Question_Number'})[['Question_Number', 'Answer']]#We are only interested in these two columns
        #Ensure the column names are consistent with the rest of the code

    def _get_weights(self, q_num):
        matches = self.weights[self.weights['question'] == q_num]
        if matches.empty:
            raise KeyError(f"No weights found for Q{q_num}")  # Changed to KeyError
        return matches.iloc[0]

    def _get_model_answer(self, q_num):
        matches = self.teacher_answers[self.teacher_answers['Question_Number'] == q_num]
        if matches.empty:
            raise KeyError(f"No model answer found for Q{q_num}")  # Changed to KeyError
        return matches['Answer'].values[0]

    # def _get_keywords(self, q_num):
    #     #Retrieve and clean keywords
    #     keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
    #     return [
    #         str(kw).strip().lower()
    #         for col in keywords.values
    #         for kw in col
    #         if pd.notna(kw) and str(kw).strip()
    #     ]

    def _get_keywords(self, q_num):
        keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
        return [
            ' '.join(str(kw).strip().lower().split())
            for col in keywords.values
            for kw in col
            if pd.notna(kw) and str(kw).strip()
        ]


    def calculate_grammar_score(self, text):
        #Calculate grammar score with error normalization
        if not text.strip():
            return 0.0

        blob = TextBlob(text)
        total_words = len(blob.words)
        if total_words == 0:
            return 0.0

        error_count = sum(
            1 for word in blob.words
            if word.spellcheck()[0][0].lower() != word.lower()
        )
        return 1 - (error_count / total_words)

    # def calculate_keyword_score(self, student_answer, q_num):
    #     #Calculate keyword match score
    #     target_keywords = self._get_keywords(q_num)
    #     if not target_keywords:
    #         return 0.0

    #     student_words = student_answer.lower().split()
    #     matches = sum(1 for kw in target_keywords if any(kw in word for word in student_words))
    #     return matches / len(target_keywords)

    def calculate_keyword_score(self, student_answer, q_num):
        target_keywords = self._get_keywords(q_num)
        if not target_keywords:
            return 0.0

        # Split student answer into words
        student_words = student_answer.lower().split()

        # Convert keywords to word sequences
        keyword_phrases = [kw.split() for kw in target_keywords]

        matches = 0
        for phrase in keyword_phrases:
            # Check for phrase using sliding window
            phrase_length = len(phrase)
            found = False
            for i in range(len(student_words) - phrase_length + 1):
                if student_words[i:i+phrase_length] == phrase:
                    found = True
                    break
            if found:
                matches += 1

        return matches / len(target_keywords)

    def calculate_semantic_score(self, student_answer, q_num):
        #Calculate semantic similarity score
        model_answer = self._get_model_answer(q_num)
        embeddings = self.model.encode([model_answer, student_answer])
        return cosine_similarity([embeddings[0]], [embeddings[1]])[0][0]

    def calculate_total_score(self, student_answer, q_num):
        weights = self._get_weights(q_num)

        # Already correct - weights are normalized to 0-1 scale

        g = self.calculate_grammar_score(student_answer) * (weights['grammarwt']/100)
        k = self.calculate_keyword_score(student_answer, q_num) * (weights['Keywordswt']/100)
        s = self.calculate_semantic_score(student_answer, q_num) * (weights['similarityWt']/100)


        print(f'Question no. {q_num}')
        print(f'Grammar Score is {g} out of {weights["grammarwt"]/100.0}')
        print(f'Keyword Score is {k} out of {weights["Keywordswt"]/100.0}')
        print(f'Semantic Score is {s} out of {weights["similarityWt"]/100.0}')

        return (g + k + s)

import pandas as pd


class ResultGenerator:
    def __init__(self):
        self.results_df = pd.DataFrame(columns=['RollNo', 'Name', 'Total', 'Percentage'])
        self.metadata_df = pd.DataFrame()

    def add_student(self, rollno, name, scores):
        # Add default 0 scores for missing questions
        for q_num in range(1, 201):
            if q_num not in scores:
                scores[q_num] = 0

        # Calculate total and percentage CORRECTLY
        max_possible = 200  # 200 questions 
        total = sum(scores.values())
        perc = (total / max_possible) * 100  # Fixed here

        self.results_df.loc[len(self.results_df)] = [rollno, name, total, perc]

        # Update metadata
        student_data = {'RollNo': rollno, 'Name': name}
        student_data.update({'Total': total, 'Percentage': perc})

        self.metadata_df = pd.concat([self.metadata_df, pd.DataFrame([student_data])], ignore_index=True)

        return [rollno, name, total, perc]

    def save_results(self):
        self.results_df.to_csv(PATHS['output']['results'], mode='a', header=False, index=False)
        self.metadata_df.to_csv(PATHS['output']['metadata'], mode='a', header=False, index=False)


#Main.py

logging.getLogger("pdfminer").setLevel(logging.ERROR)

def evaluate_student(pdf_path, rollno, name, start_page=1):
    # Initialize components
    processor = PDFProcessor(start_page)
    parser = AnswerParser()
    scorer = ScoringEngine()
    reporter = ResultGenerator()

    # Process PDF
    raw_text = processor.extract_text(pdf_path)
    # clean_text = parser.preprocess_pdf_text(raw_text)  # Static method call
    answers = parser.parse(pdf_path)  # Instance method

    # Score answers with detailed logging
    scores = {}
    for q_num, answer_text in answers.items():
        try:
            # answer_text = answer_data['answer']
            score = scorer.calculate_total_score(answer_text, q_num)
            print(f"Q{q_num}: {score:.2f}/1.0")  # Print individual scores
            scores[q_num] = score
        except KeyError as e:
            print(f"\n⚠️ Skipping Q{q_num}: {str(e)}")
        except Exception as e:
            print(f"\n❌ Error processing Q{q_num}: {str(e)}")

    # Generate reports
    reporter.add_student(rollno, name, scores)
    reporter.save_results()
    total = sum(scores.values())
    max_score = len(answers)
    print(f"\nProcessed {name} ({rollno}). Total: {total}/{max_score} ({total/max_score*100:.2f}%)")



def colab_evaluate_student():
    # Input parameters
    rollno = input("Enter Roll Number: ")
    name = input("Enter Student Name: ")
    start_page = int(input("Start page [1]: ") or 1)

    # try:
        # Verify PDF path
    pdf_path = PATHS['data']
    if not os.path.isfile(pdf_path):
      raise FileNotFoundError(f"PDF not found: {pdf_path}")

        # Process evaluation
    evaluate_student(pdf_path, rollno, name, start_page)
    print("\n✅ Evaluation Complete!")

    # except Exception as e:
        # print(f"\n❌ Error: {str(e)}")


colab_evaluate_student()
# Out:
# Enter Roll Number: 6
# Enter Student Name: F
# Start page [1]: 1
# Question no. 1
# Grammar Score is 0.07727272727272727 out of 0.1
# Keyword Score is 0.4 out of 0.4
# Semantic Score is 0.5000000596046448 out of 0.5
# Q1: 0.98/1.0
# Question no. 2
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q2: 1.00/1.0
# Question no. 3
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q3: 0.83/1.0
# Question no. 4
# Grammar Score is 0.16363636363636364 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q4: 0.71/1.0
# Question no. 5
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q5: 0.58/1.0
# Question no. 6
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q6: 0.88/1.0
# Question no. 7
# Grammar Score is 0.15200000000000002 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q7: 0.87/1.0
# Question no. 8
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q8: 0.92/1.0
# Question no. 9
# Grammar Score is 0.14285714285714288 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q9: 0.53/1.0
# Question no. 10
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q10: 0.82/1.0
# Question no. 11
# Grammar Score is 0.19166666666666668 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q11: 0.99/1.0
# Question no. 12
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q12: 0.98/1.0
# Question no. 13
# Grammar Score is 0.18095238095238098 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q13: 0.73/1.0
# Question no. 14
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q14: 1.00/1.0
# Question no. 15
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q15: 0.98/1.0
# Question no. 16
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q16: 0.98/1.0
# Question no. 17
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q17: 0.83/1.0
# Question no. 18
# Grammar Score is 0.09615384615384616 out of 0.1
# Keyword Score is 0.13333333333333333 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q18: 0.73/1.0
# Question no. 19
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q19: 0.98/1.0
# Question no. 20
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q20: 0.99/1.0
# Question no. 21
# Grammar Score is 0.17272727272727273 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q21: 0.56/1.0
# Question no. 22
# Grammar Score is 0.18823529411764706 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
#
out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q127: 0.82/1.0
# Question no. 128
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q128: 0.73/1.0
# Question no. 129
# Grammar Score is 0.168 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q129: 0.55/1.0
# Question no. 130
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q130: 1.00/1.0
# Question no. 131
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q131: 0.99/1.0
# Question no. 132
# Grammar Score is 0.19230769230769232 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q132: 0.99/1.0
# Question no. 133
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29803515672683717 out of 0.3
# Q133: 0.66/1.0
# Question no. 134
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29955210685729977 out of 0.3
# Q134: 1.00/1.0
# Question no. 135
# Grammar Score is 0.15 out of 0.15
# Keyword Score is 0.19999999999999998 out of 0.6
# Semantic Score is 0.25 out of 0.25
# Q135: 0.60/1.0
# Question no. 136
# Grammar Score is 0.15555555555555556 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q136: 0.62/1.0
# Question no. 137
# Grammar Score is 0.18461538461538463 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q137: 0.98/1.0
# Question no. 138
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q138: 0.82/1.0
# Question no. 139
# Grammar Score is 0.18095238095238098 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q139: 0.98/1.0
# Question no. 140
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q140: 0.72/1.0
# Question no. 141
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q141: 0.72/1.0
# Question no. 142
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q142: 1.00/1.0
# Question no. 143
# Grammar Score is 0.17333333333333334 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q143: 0.64/1.0
# Question no. 144
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q144: 0.66/1.0
# Question no. 145
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q145: 1.00/1.0
# Question no. 146
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q146: 0.97/1.0
# Question no. 147
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q147: 0.98/1.0
# Question no. 148
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q148: 1.00/1.0
# Question no. 149
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q149: 0.99/1.0
# Question no. 150
# Grammar Score is 0.12307692307692308 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q150: 0.67/1.0
# Question no. 151
# Grammar Score is 0.15714285714285714 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q151: 0.62/1.0
# Question no. 152
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q152: 0.98/1.0
# Question no. 153
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q153: 0.45/1.0
# Question no. 154
# Grammar Score is 0.12307692307692308 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q154: 0.42/1.0
# Question no. 155
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q155: 0.67/1.0
# Question no. 156
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q156: 0.46/1.0
# Question no. 157
# Grammar Score is 0.15714285714285714 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q157: 0.54/1.0
# Question no. 158
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q158: 0.64/1.0
# Question no. 159
# Grammar Score is 0.18181818181818182 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q159: 0.73/1.0
# Question no. 160
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q160: 0.57/1.0
# Question no. 161
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q161: 0.56/1.0
# Question no. 162
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q162: 0.47/1.0
# Question no. 163
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q163: 0.67/1.0
# Question no. 164
# Grammar Score is 0.08000000000000002 out of 0.1
# Keyword Score is 0.2 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q164: 0.78/1.0
# Question no. 165
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q165: 0.80/1.0
# Question no. 166
# Grammar Score is 0.15384615384615385 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
#
out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q200: 0.55/1.0
#
# Processed F (6). Total: 154.69310194676163/200 (77.35%)
#
# ✅ Evaluation Complete!

# %% [markdown]
# # Test 3
#
# More hurdles added, text is misalligned Question headings are non uniform and Answering order is changed 1 can be answered after answering Q5

# %%
# !pip install pymupdf pdfplumber pandas numpy easyocr pdf2image nltk scikit-learn sentence-transformers flask reportlab textblob
# !pip install --upgrade pymupdf
import fitz
import pdfplumber
import re
import os
import logging
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
import os
import argparse
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/

PATHS = {
    # Core datasets
    'questions': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/QuestionAnswersDataSet.csv',
    'keywords': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Keywords.csv',
    'weights': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Evaluation_Weightage.csv',

    # Output files
    'output': {
        'results': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/results.csv',
        'metadata': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/result_metadata.csv'
    },

    # PDF input
    'data': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/Test/test_anomalous (2).pdf'
}
import fitz
class PDFProcessor:
    def __init__(self, start_page=1):
        self.start_page = start_page - 1  # 0-based index
        logging.getLogger("pdfminer").setLevel(logging.ERROR)

    def extract_text(self, pdf_path):
        doc = fitz.open(pdf_path)
        full_text = ""
        for page_num in range(self.start_page, len(doc)):
            full_text += doc[page_num].get_text()
        return full_text


import pdfplumber
import re

class AnswerParser:
    def __init__(self):
        # Comprehensive question pattern
        self.question_pattern = re.compile(
            r'(?:^|\n)(?:Q|Question|Problem|\d+)[\s.)-]*\s*(\d+)[\s:)-]*',
            re.IGNORECASE
        )

    def parse(self, pdf_path):
        """Parse PDF into {q_num: answer_text} using layout analysis"""
        answers = {}
        current_q = None
        answer_buffer = []

        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                # Extract text with layout preservation
                text = page.extract_text(layout=True, x_tolerance=5, y_tolerance=2)

                # Process text in order of appearance
                for line in text.split('\n'):
                    line = line.strip()
                    if not line:
                        continue

                    # Check for new question
                    match = self.question_pattern.search(line)
                    if match:
                        # Save previous answer
                        if current_q is not None:
                            answers[current_q] = ' '.join(answer_buffer).strip()
                            answer_buffer = []

                        current_q = int(match.group(1))
                        answer_start = match.end()
                        answer_buffer.append(line[answer_start:].strip())
                    else:
                        # Continue current answer
                        if current_q is not None:
                            answer_buffer.append(line)

        # Save last answer
        if current_q is not None:
            answers[current_q] = ' '.join(answer_buffer).strip()

        return self._merge_split_answers(answers)

    def _merge_split_answers(self, answers):
        """Merge answers split across pages/pages"""
        merged = {}
        sorted_qs = sorted(answers.keys())

        for q_num in sorted_qs:
            answer = answers[q_num]

            # Check if previous answer ends with continuation marker
            if q_num-1 in merged and merged[q_num-1].endswith((' ', '-')):
                merged[q_num-1] += ' ' + answer
            else:
                merged[q_num] = answer

        return merged

import os
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

class ScoringEngine:
    def __init__(self):
        #Initialize with paths from config
        self.weights = self._load_data('weights')
        self.keywords = self._load_data('keywords')
        self.teacher_answers = self._load_answers('questions')
        self.model = SentenceTransformer('all-MiniLM-L6-v2')

    def _load_data(self, path_key):
        path = PATHS[path_key]
        if not path or not os.path.exists(path):
            raise FileNotFoundError(f"Path not found: {path}")
        return pd.read_csv(path, encoding='latin1')

    def _load_answers(self, path_key):
        #Specialized answer loader with column renaming
        df = self._load_data(path_key)
        return df.rename(columns={'Question Number': 'Question_Number'})[['Question_Number', 'Answer']]#We are only interested in these two columns
        #Ensure the column names are consistent with the rest of the code

    def _get_weights(self, q_num):
        matches = self.weights[self.weights['question'] == q_num]
        if matches.empty:
            raise KeyError(f"No weights found for Q{q_num}")  # Changed to KeyError
        return matches.iloc[0]

    def _get_model_answer(self, q_num):
        matches = self.teacher_answers[self.teacher_answers['Question_Number'] == q_num]
        if matches.empty:
            raise KeyError(f"No model answer found for Q{q_num}")  # Changed to KeyError
        return matches['Answer'].values[0]

    # def _get_keywords(self, q_num):
    #     #Retrieve and clean keywords
    #     keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
    #     return [
    #         str(kw).strip().lower()
    #         for col in keywords.values
    #         for kw in col
    #         if pd.notna(kw) and str(kw).strip()
    #     ]

    def _get_keywords(self, q_num):
        keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
        return [
            ' '.join(str(kw).strip().lower().split())
            for col in keywords.values
            for kw in col
            if pd.notna(kw) and str(kw).strip()
        ]


    def calculate_grammar_score(self, text):
        #Calculate grammar score with error normalization
        if not text.strip():
            return 0.0

        blob = TextBlob(text)
        total_words = len(blob.words)
        if total_words == 0:
            return 0.0

        error_count = sum(
            1 for word in blob.words
            if word.spellcheck()[0][0].lower() != word.lower()
        )
        return 1 - (error_count / total_words)

    # def calculate_keyword_score(self, student_answer, q_num):
    #     #Calculate keyword match score
    #     target_keywords = self._get_keywords(q_num)
    #     if not target_keywords:
    #         return 0.0

    #     student_words = student_answer.lower().split()
    #     matches = sum(1 for kw in target_keywords if any(kw in word for word in student_words))
    #     return matches / len(target_keywords)

    def calculate_keyword_score(self, student_answer, q_num):
        target_keywords = self._get_keywords(q_num)
        if not target_keywords:
            return 0.0

        # Split student answer into words
        student_words = student_answer.lower().split()

        # Convert keywords to word sequences
        keyword_phrases = [kw.split() for kw in target_keywords]

        matches = 0
        for phrase in keyword_phrases:
            # Check for phrase using sliding window
            phrase_length = len(phrase)
            found = False
            for i in range(len(student_words) - phrase_length + 1):
                if student_words[i:i+phrase_length] == phrase:
                    found = True
                    break
            if found:
                matches += 1

        return matches / len(target_keywords)

    def calculate_semantic_score(self, student_answer, q_num):
        #Calculate semantic similarity score
        model_answer = self._get_model_answer(q_num)
        embeddings = self.model.encode([model_answer, student_answer])
        return cosine_similarity([embeddings[0]], [embeddings[1]])[0][0]

    def calculate_total_score(self, student_answer, q_num):
        weights = self._get_weights(q_num)

        # Already correct - weights are normalized to 0-1 scale

        g = self.calculate_grammar_score(student_answer) * (weights['grammarwt']/100)
        k = self.calculate_keyword_score(student_answer, q_num) * (weights['Keywordswt']/100)
        s = self.calculate_semantic_score(student_answer, q_num) * (weights['similarityWt']/100)


        print(f'Question no. {q_num}')
        print(f'Grammar Score is {g} out of {weights["grammarwt"]/100.0}')
        print(f'Keyword Score is {k} out of {weights["Keywordswt"]/100.0}')
        print(f'Semantic Score is {s} out of {weights["similarityWt"]/100.0}')

        return (g + k + s)

import pandas as pd


class ResultGenerator:
    def __init__(self):
        self.results_df = pd.DataFrame(columns=['RollNo', 'Name', 'Total', 'Percentage'])
        self.metadata_df = pd.DataFrame()

    def add_student(self, rollno, name, scores):
        # Add default 0 scores for missing questions
        for q_num in range(1, 201):
            if q_num not in scores:
                scores[q_num] = 0

        # Calculate total and percentage CORRECTLY
        max_possible = 200  # 200 questions
        total = sum(scores.values())
        perc = (total / max_possible) * 100  # Fixed here

        self.results_df.loc[len(self.results_df)] = [rollno, name, total, perc]

        # Update metadata
        student_data = {'RollNo': rollno, 'Name': name}
        student_data.update({'Total': total, 'Percentage': perc})

        self.metadata_df = pd.concat([self.metadata_df, pd.DataFrame([student_data])], ignore_index=True)

        return [rollno, name, total, perc]

    def save_results(self):
        self.results_df.to_csv(PATHS['output']['results'], mode='a', header=False, index=False)
        self.metadata_df.to_csv(PATHS['output']['metadata'], mode='a', header=False, index=False)


#Main.py

logging.getLogger("pdfminer").setLevel(logging.ERROR)

def evaluate_student(pdf_path, rollno, name, start_page=1):
    # Initialize components
    processor = PDFProcessor(start_page)
    parser = AnswerParser()
    scorer = ScoringEngine()
    reporter = ResultGenerator()

    # Process PDF
    raw_text = processor.extract_text(pdf_path)
    # clean_text = parser.preprocess_pdf_text(raw_text)  # Static method call
    answers = parser.parse(pdf_path)  # Instance method

    # Score answers with detailed logging
    scores = {}
    for q_num, answer_text in answers.items():
        try:
            # answer_text = answer_data['answer']
            score = scorer.calculate_total_score(answer_text, q_num)
            print(f"Q{q_num}: {score:.2f}/1.0")  # Print individual scores
            scores[q_num] = score
        except KeyError as e:
            print(f"\n⚠️ Skipping Q{q_num}: {str(e)}")
        except Exception as e:
            print(f"\n❌ Error processing Q{q_num}: {str(e)}")

    # Generate reports
    reporter.add_student(rollno, name, scores)
    reporter.save_results()
    total = sum(scores.values())
    max_score = len(answers)
    print(f"\nProcessed {name} ({rollno}). Total: {total}/{max_score} ({total/max_score*100:.2f}%)")



def colab_evaluate_student():
    # Input parameters
    rollno = input("Enter Roll Number: ")
    name = input("Enter Student Name: ")
    start_page = int(input("Start page [1]: ") or 1)

    # try:
        # Verify PDF path
    pdf_path = PATHS['data']
    if not os.path.isfile(pdf_path):
      raise FileNotFoundError(f"PDF not found: {pdf_path}")

        # Process evaluation
    evaluate_student(pdf_path, rollno, name, start_page)
    print("\n✅ Evaluation Complete!")

    # except Exception as e:
        # print(f"\n❌ Error: {str(e)}")


colab_evaluate_student()
# Out:
# /content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System
# Enter Roll Number: 7
# Enter Student Name: G
# Start page [1]: 1
#
# ⚠️ Skipping Q0: 'No weights found for Q0'
# Question no. 1
# Grammar Score is 0.1 out of 0.1
# Keyword Score is 0.0 out of 0.4
# Semantic Score is 0.1341467797756195 out of 0.5
# Q1: 0.23/1.0
# Question no. 2
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q2: 1.00/1.0
# Question no. 3
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.018051613122224808 out of 0.3
# Q3: 0.19/1.0
# Question no. 4
# Grammar Score is 0.16363636363636364 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.007958633825182915 out of 0.3
# Q4: 0.17/1.0
# Question no. 5
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.045598626136779785 out of 0.3
# Q5: 0.22/1.0
# Question no. 6
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.053435057401657104 out of 0.3
# Q6: 0.23/1.0
# Question no. 7
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.013925193250179291 out of 0.3
# Q7: 0.19/1.0
# Question no. 8
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.043138915300369264 out of 0.3
# Q8: 0.19/1.0
# Question no. 9
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is -0.006177203357219696 out of 0.3
# Q9: 0.18/1.0
# Question no. 11
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q11: 1.00/1.0
# Question no. 12
# Grammar Score is 0.18888888888888888 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q12: 0.99/1.0
# Question no. 13
# Grammar Score is 0.18095238095238098 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q13: 0.73/1.0
# Question no. 16
# Grammar Score is 0.18888888888888888 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q16: 0.99/1.0
# Question no. 17
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q17: 0.83/1.0
# Question no. 20
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q20: 0.99/1.0
# Question no. 21
# Grammar Score is 0.16444444444444445 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.2880200386047363 out of 0.3
# Q21: 0.54/1.0
# Question no. 22
# Grammar Score is 0.18823529411764706 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q22: 0.82/1.0
# Question no. 23
# Grammar Score is 0.19047619047619047 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q23: 0.99/1.0
# Question no. 24
# Grammar Score is 0.18888888888888888 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q24: 0.82/1.0
# Question no. 25
# Grammar Score is 0.18947368421052635 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q25: 0.99/1.0
# Question no. 26
# Grammar Score is 0.19047619047619047 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q26: 0.82/1.0
# Question no. 27
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q27: 0.67/1.0
# Question no. 28
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q28: 0.82/1.0
# Question no. 30
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q30: 0.73/1.0
# Question no. 31
# Grammar Score is 0.1625 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q31: 0.80/1.0
# Question no. 32
# Grammar Score is 0.12222222222222223 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q32: 0.92/1.0
# Question no. 34
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q34: 0.49/1.0
# Question no. 35
# Grammar Score is 0.14285714285714288 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q35: 0.44/1.0
# Question no. 36
# Grammar Score is 0.18666666666666668 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999994635581967 out of 0.3
# Q36: 0.99/1.0
# Question no. 40
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q40: 0.83/1.0
# Question no. 42
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999992847442625 out of 0.3
# Q42: 0.82/1.0
# Question no. 43
# Grammar Score is 0.18823529411764706 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q43: 0.99/1.0
# Question no. 44
# Grammar Score is 0.15789473684210528 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q44: 0.62/1.0
# Question no. 45
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q45: 0.80/1.0
# Question no. 46
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q46: 0.99/1.0
# Question no. 47
# Grammar Score is 0.17894736842105263 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q47: 0.98/1.0
# Question no. 48
# Grammar Score is 0.18260869565217394 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q48: 0.98/1.0
# Question no. 49
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q49: 0.64/1.0
# Question no. 50
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q50: 0.82/1.0
# Question no. 51
# Grammar Score is 0.08461538461538462 out of 0.1
# Keyword Score is 0.2 out of 0.4
# Semantic Score is 0.4999999701976776 out of 0.5
# Q51: 0.78/1.0
# Question no. 52
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q52: 0.75/1.0
# Question no. 54
# Grammar Score is 0.09166666666666667 out of 0.1
# Keyword Score is 0.06666666666666667 out of 0.4
# Semantic Score is 0.5000000596046448 out of 0.5
# Q54: 0.66/1.0
# Question no. 55
# Grammar Score is 0.08333333333333334 out of 0.1
# Keyword Score is 0.26666666666666666 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q55: 0.85/1.0
# Question no. 56
# Grammar Score is 0.08000000000000002 out of 0.1
# Keyword Score is 0.26666666666666666 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q56: 0.85/1.0
# Question no. 59
# Grammar Score is 0.17391304347826086 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q59: 0.64/1.0
# Question no. 60
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.24673054218292234 out of 0.3
# Q60: 0.59/1.0
# Question no. 61
# Grammar Score is 0.16842105263157894 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q61: 0.97/1.0
# Question no. 62
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q62: 0.45/1.0
# Question no. 63
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.2955979585647583 out of 0.3
# Q63: 0.97/1.0
# Question no. 64
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q64: 0.98/1.0
# Question no. 65
# Grammar Score is 0.19 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q65: 0.99/1.0
# Question no. 66
# Grammar Score is 0.1 out of 0.1
# Keyword Score is 0.13333333333333333 out of 0.4
# Semantic Score is 0.5000000596046448 out of 0.5
# Q66: 0.73/1.0
# Question no. 67
# Grammar Score is 0.09230769230769231 out of 0.1
# Keyword Score is 0.33333333333333337 out of 0.4
# Semantic Score is 0.4999999403953552 out of 0.5
# Q67: 0.93/1.0
# Question no. 68
# Grammar Score is 0.1625 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q68: 0.80/1.0
# Question no. 69
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29863446950912476 out of 0.3
# Q69: 0.65/1.0
# Question no. 70
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29999994635581967 out of 0.3
# Q70: 0.64/1.0
# Question no. 71
# Grammar Score is 0.18947368421052635 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q71: 0.74/1.0
# Question no. 72
# Grammar Score is 0.1375 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q72: 0.85/1.0
# Question no. 74
# Grammar Score is 0.18181818181818182 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q74: 0.98/1.0
# Question no. 75
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q75: 0.73/1.0
# Question no. 76
# Grammar Score is 0.17894736842105263 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q76: 0.65/1.0
# Question no. 78
# Grammar Score is 0.17333333333333334 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q78: 0.72/1.0
# Question no. 79
# Grammar Score is 0.16470588235294117 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q79: 0.96/1.0
# Question no. 80
# Grammar Score is 0.15555555555555556 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q80: 0.96/1.0
# Question no. 81
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q81: 0.89/1.0
# Question no. 87
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q87: 0.75/1.0
# Question no. 88
# Grammar Score is 0.17894736842105263 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q88: 0.90/1.0
# Question no. 89
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q89: 1.00/1.0
# Question no. 90
# Grammar Score is 0.18888888888888888 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q90: 0.99/1.0
# Question no. 92
# Grammar Score is 0.1466666666666667 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q92: 0.53/1.0
# Question no. 93
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q93: 0.63/1.0
# Question no. 94
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q94: 0.46/1.0
# Question no. 96
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q96: 1.00/1.0
# Question no. 98
# Grammar Score is 0.1466666666666667 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q98: 0.78/1.0
# Question no. 99
# Grammar Score is 0.18666666666666668 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q99: 0.99/1.0
# Question no. 102
# Grammar Score is 0.12307692307692308 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q102: 0.67/1.0
# Question no. 103
# Grammar Score is 0.18947368421052635 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q103: 0.82/1.0
# Question no. 104
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q104: 0.73/1.0
# Question no. 105
# Grammar Score is 0.168 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q105: 0.55/1.0
# Question no. 106
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q106: 1.00/1.0
# Question no. 110
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29955210685729977 out of 0.3
# Q110: 1.00/1.0
# Question no. 113
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q113: 0.97/1.0
# Question no. 114
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q114: 0.82/1.0
# Question no. 117
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q117: 0.72/1.0
# Question no. 118
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q118: 1.00/1.0
# Question no. 120
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q120: 0.66/1.0
# Question no. 122
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q122: 0.97/1.0
# Question no. 123
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q123: 0.98/1.0
# Question no. 128
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q128: 0.73/1.0
# Question no. 129
# Grammar Score is 0.168 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.2947599649429321 out of 0.3
# Q129: 0.55/1.0
# Question no. 130
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q130: 1.00/1.0
# Question no. 132
# Grammar Score is 0.19230769230769232 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q132: 0.99/1.0
# Question no. 133
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q133: 0.65/1.0
# Question no. 135
# Grammar Score is 0.15 out of 0.15
# Keyword Score is 0.19999999999999998 out of 0.6
# Semantic Score is 0.25 out of 0.25
# Q135: 0.60/1.0
# Question no. 136
# Grammar Score is 0.15555555555555556 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q136: 0.62/1.0
# Question no. 137
# Grammar Score is 0.18461538461538463 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q137: 0.98/1.0
# Question no. 138
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q138: 0.82/1.0
# Question no. 139
# Grammar Score is 0.18095238095238098 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q139: 0.98/1.0
# Question no. 142
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q142: 1.00/1.0
# Question no. 143
# Grammar Score is 0.17333333333333334 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q143: 0.64/1.0
# Question no. 144
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q144: 0.66/1.0
# Question no. 145
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q145: 1.00/1.0
# Question no. 149
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q149: 0.99/1.0
# Question no. 151
# Grammar Score is 0.15714285714285714 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q151: 0.62/1.0
# Question no. 152
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q152: 0.98/1.0
# Question no. 153
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q153: 0.45/1.0
# Question no. 154
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.20717006921768188 out of 0.3
# Q154: 0.36/1.0
# Question no. 155
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q155: 0.67/1.0
# Question no. 157
# Grammar Score is 0.15714285714285714 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q157: 0.54/1.0
# Question no. 158
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q158: 0.64/1.0
# Question no. 159
# Grammar Score is 0.18181818181818182 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q159: 0.73/1.0
# Question no. 160
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q160: 0.57/1.0
# Question no. 161
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q161: 0.56/1.0
# Question no. 162
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q162: 0.47/1.0
# Question no. 163
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q163: 0.67/1.0
# Question no. 164
# Grammar Score is 0.08000000000000002 out of 0.1
# Keyword Score is 0.2 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q164: 0.78/1.0
# Question no. 165
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q165: 0.80/1.0
# Question no. 167
# Grammar Score is 0.16470588235294117 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q167: 0.63/1.0
# Question no. 168
# Grammar Score is 0.08571428571428573 out of 0.1
# Keyword Score is 0.0 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q168: 0.59/1.0
# Question no. 169
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q169: 0.64/1.0
# Question no. 171
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q171: 0.57/1.0
# Question no. 172
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q172: 0.58/1.0
# Question no. 175
# Grammar Score is 0.09000000000000001 out of 0.1
# Keyword Score is 0.4 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q175: 0.99/1.0
# Question no. 177
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q177: 0.54/1.0
# Question no. 178
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q178: 0.71/1.0
# Question no. 179
# Grammar Score is 0.14285714285714288 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q179: 0.94/1.0
# Question no. 180
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q180: 0.74/1.0
# Question no. 181
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q181: 0.57/1.0
# Question no. 183
# Grammar Score is 0.13333333333333336 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q183: 0.60/1.0
# Question no. 184
# Grammar Score is 0.13333333333333336 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q184: 0.43/1.0
# Question no. 185
# Grammar Score is 0.15384615384615385 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q185: 0.45/1.0
# Question no. 186
# Grammar Score is 0.09166666666666667 out of 0.1
# Keyword Score is 0.06666666666666667 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q186: 0.66/1.0
# Question no. 187
# Grammar Score is 0.15384615384615385 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q187: 0.54/1.0
# Question no. 189
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q189: 1.00/1.0
# Question no. 192
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q192: 0.79/1.0
# Question no. 194
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q194: 0.67/1.0
# Question no. 195
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q195: 0.63/1.0
# Question no. 196
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q196: 0.48/1.0
# Question no. 197
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q197: 0.75/1.0
# Question no. 199
# Grammar Score is 0.16363636363636364 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q199: 0.55/1.0
# Question no. 200
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.29662370681762695 out of 0.3
# Q200: 0.55/1.0
#
# Processed G (7). Total: 103.7072746407138/142 (73.03%)
#
# ✅ Evaluation Complete!

# %% [markdown]
# # Test 4
#
# The most erronous pdf. It even has errors in answers's text that is keywords missing, grammatical error, non-similarity etc.

# %%
# !pip install pymupdf pdfplumber pandas numpy easyocr pdf2image nltk scikit-learn sentence-transformers flask reportlab textblob
# !pip install --upgrade pymupdf
import fitz
import pdfplumber
import re
import os
import logging
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
import os
import argparse
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Project/Project/Answer\ Sheet\ Evaluation\ System/

PATHS = {
    # Core datasets
    'questions': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/QuestionAnswersDataSet.csv',
    'keywords': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Keywords.csv',
    'weights': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/data/Evaluation_Weightage.csv',

    # Output files
    'output': {
        'results': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/results.csv',
        'metadata': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/results/result_metadata.csv'
    },

    # PDF input
    'data': '/content/drive/MyDrive/Project/Project/Answer Sheet Evaluation System/Test/test_anomalous_refined (1).pdf'
}
import fitz
class PDFProcessor:
    def __init__(self, start_page=1):
        self.start_page = start_page - 1  # 0-based index
        logging.getLogger("pdfminer").setLevel(logging.ERROR)

    def extract_text(self, pdf_path):
        doc = fitz.open(pdf_path)
        full_text = ""
        for page_num in range(self.start_page, len(doc)):
            full_text += doc[page_num].get_text()
        return full_text


import pdfplumber
import re

class AnswerParser:
    def __init__(self):
        # Comprehensive question pattern
        self.question_pattern = re.compile(
            r'(?:^|\n)(?:Q|Question|Problem|\d+)[\s.)-]*\s*(\d+)[\s:)-]*',
            re.IGNORECASE
        )

    def parse(self, pdf_path):
        """Parse PDF into {q_num: answer_text} using layout analysis"""
        answers = {}
        current_q = None
        answer_buffer = []

        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                # Extract text with layout preservation
                text = page.extract_text(layout=True, x_tolerance=5, y_tolerance=2)

                # Process text in order of appearance
                for line in text.split('\n'):
                    line = line.strip()
                    if not line:
                        continue

                    # Check for new question
                    match = self.question_pattern.search(line)
                    if match:
                        # Save previous answer
                        if current_q is not None:
                            answers[current_q] = ' '.join(answer_buffer).strip()
                            answer_buffer = []

                        current_q = int(match.group(1))
                        answer_start = match.end()
                        answer_buffer.append(line[answer_start:].strip())
                    else:
                        # Continue current answer
                        if current_q is not None:
                            answer_buffer.append(line)

        # Save last answer
        if current_q is not None:
            answers[current_q] = ' '.join(answer_buffer).strip()

        return self._merge_split_answers(answers)

    def _merge_split_answers(self, answers):
        """Merge answers split across pages/pages"""
        merged = {}
        sorted_qs = sorted(answers.keys())

        for q_num in sorted_qs:
            answer = answers[q_num]

            # Check if previous answer ends with continuation marker
            if q_num-1 in merged and merged[q_num-1].endswith((' ', '-')):
                merged[q_num-1] += ' ' + answer
            else:
                merged[q_num] = answer

        return merged

import os
import pandas as pd
from textblob import TextBlob
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

class ScoringEngine:
    def __init__(self):
        #Initialize with paths from config
        self.weights = self._load_data('weights')
        self.keywords = self._load_data('keywords')
        self.teacher_answers = self._load_answers('questions')
        self.model = SentenceTransformer('all-MiniLM-L6-v2')

    def _load_data(self, path_key):
        path = PATHS[path_key]
        if not path or not os.path.exists(path):
            raise FileNotFoundError(f"Path not found: {path}")
        return pd.read_csv(path, encoding='latin1')

    def _load_answers(self, path_key):
        #Specialized answer loader with column renaming
        df = self._load_data(path_key)
        return df.rename(columns={'Question Number': 'Question_Number'})[['Question_Number', 'Answer']]#We are only interested in these two columns
        #Ensure the column names are consistent with the rest of the code

    def _get_weights(self, q_num):
        matches = self.weights[self.weights['question'] == q_num]
        if matches.empty:
            raise KeyError(f"No weights found for Q{q_num}")  # Changed to KeyError
        return matches.iloc[0]

    def _get_model_answer(self, q_num):
        matches = self.teacher_answers[self.teacher_answers['Question_Number'] == q_num]
        if matches.empty:
            raise KeyError(f"No model answer found for Q{q_num}")  # Changed to KeyError
        return matches['Answer'].values[0]

    # def _get_keywords(self, q_num):
    #     #Retrieve and clean keywords
    #     keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
    #     return [
    #         str(kw).strip().lower()
    #         for col in keywords.values
    #         for kw in col
    #         if pd.notna(kw) and str(kw).strip()
    #     ]

    def _get_keywords(self, q_num):
        keywords = self.keywords[self.keywords['Question Number'] == q_num].iloc[:, 1:]
        return [
            ' '.join(str(kw).strip().lower().split())
            for col in keywords.values
            for kw in col
            if pd.notna(kw) and str(kw).strip()
        ]


    def calculate_grammar_score(self, text):
        #Calculate grammar score with error normalization
        if not text.strip():
            return 0.0

        blob = TextBlob(text)
        total_words = len(blob.words)
        if total_words == 0:
            return 0.0

        error_count = sum(
            1 for word in blob.words
            if word.spellcheck()[0][0].lower() != word.lower()
        )
        return 1 - (error_count / total_words)

    # def calculate_keyword_score(self, student_answer, q_num):
    #     #Calculate keyword match score
    #     target_keywords = self._get_keywords(q_num)
    #     if not target_keywords:
    #         return 0.0

    #     student_words = student_answer.lower().split()
    #     matches = sum(1 for kw in target_keywords if any(kw in word for word in student_words))
    #     return matches / len(target_keywords)

    def calculate_keyword_score(self, student_answer, q_num):
        target_keywords = self._get_keywords(q_num)
        if not target_keywords:
            return 0.0

        # Split student answer into words
        student_words = student_answer.lower().split()

        # Convert keywords to word sequences
        keyword_phrases = [kw.split() for kw in target_keywords]

        matches = 0
        for phrase in keyword_phrases:
            # Check for phrase using sliding window
            phrase_length = len(phrase)
            found = False
            for i in range(len(student_words) - phrase_length + 1):
                if student_words[i:i+phrase_length] == phrase:
                    found = True
                    break
            if found:
                matches += 1

        return matches / len(target_keywords)

    def calculate_semantic_score(self, student_answer, q_num):
        #Calculate semantic similarity score
        model_answer = self._get_model_answer(q_num)
        embeddings = self.model.encode([model_answer, student_answer])
        return cosine_similarity([embeddings[0]], [embeddings[1]])[0][0]

    def calculate_total_score(self, student_answer, q_num):
        weights = self._get_weights(q_num)

        # Already correct - weights are normalized to 0-1 scale

        g = self.calculate_grammar_score(student_answer) * (weights['grammarwt']/100)
        k = self.calculate_keyword_score(student_answer, q_num) * (weights['Keywordswt']/100)
        s = self.calculate_semantic_score(student_answer, q_num) * (weights['similarityWt']/100)


        print(f'Question no. {q_num}')
        print(f'Grammar Score is {g} out of {weights["grammarwt"]/100.0}')
        print(f'Keyword Score is {k} out of {weights["Keywordswt"]/100.0}')
        print(f'Semantic Score is {s} out of {weights["similarityWt"]/100.0}')

        return (g + k + s)

import pandas as pd


class ResultGenerator:
    def __init__(self):
        self.results_df = pd.DataFrame(columns=['RollNo', 'Name', 'Total', 'Percentage'])
        self.metadata_df = pd.DataFrame()

    def add_student(self, rollno, name, scores):
        # Add default 0 scores for missing questions
        for q_num in range(1, 201):
            if q_num not in scores:
                scores[q_num] = 0

        # Calculate total and percentage CORRECTLY
        max_possible = 200  # 200 questions 
        total = sum(scores.values())
        perc = (total / max_possible) * 100  # Fixed here

        self.results_df.loc[len(self.results_df)] = [rollno, name, total, perc]

        # Update metadata
        student_data = {'RollNo': rollno, 'Name': name}
        student_data.update({'Total': total, 'Percentage': perc})

        self.metadata_df = pd.concat([self.metadata_df, pd.DataFrame([student_data])], ignore_index=True)

        return [rollno, name, total, perc]

    def save_results(self):
        self.results_df.to_csv(PATHS['output']['results'], mode='a', header=False, index=False)
        self.metadata_df.to_csv(PATHS['output']['metadata'], mode='a', header=False, index=False)


#Main.py

logging.getLogger("pdfminer").setLevel(logging.ERROR)

def evaluate_student(pdf_path, rollno, name, start_page=1):
    # Initialize components
    processor = PDFProcessor(start_page)
    parser = AnswerParser()
    scorer = ScoringEngine()
    reporter = ResultGenerator()

    # Process PDF
    raw_text = processor.extract_text(pdf_path)
    # clean_text = parser.preprocess_pdf_text(raw_text)  # Static method call
    answers = parser.parse(pdf_path)  # Instance method

    # Score answers with detailed logging
    scores = {}
    for q_num, answer_text in answers.items():
        try:
            # answer_text = answer_data['answer']
            score = scorer.calculate_total_score(answer_text, q_num)
            print(f"Q{q_num}: {score:.2f}/1.0")  # Print individual scores
            scores[q_num] = score
        except KeyError as e:
            print(f"\n⚠️ Skipping Q{q_num}: {str(e)}")
        except Exception as e:
            print(f"\n❌ Error processing Q{q_num}: {str(e)}")

    # Generate reports
    reporter.add_student(rollno, name, scores)
    reporter.save_results()
    total = sum(scores.values())
    max_score = len(answers)
    print(f"\nProcessed {name} ({rollno}). Total: {total}/{max_score} ({total/max_score*100:.2f}%)")



def colab_evaluate_student():
    # Input parameters
    rollno = input("Enter Roll Number: ")
    name = input("Enter Student Name: ")
    start_page = int(input("Start page [1]: ") or 1)

    # try:
        # Verify PDF path
    pdf_path = PATHS['data']
    if not os.path.isfile(pdf_path):
      raise FileNotFoundError(f"PDF not found: {pdf_path}")

        # Process evaluation
    evaluate_student(pdf_path, rollno, name, start_page)
    print("\n✅ Evaluation Complete!")

    # except Exception as e:
        # print(f"\n❌ Error: {str(e)}")


colab_evaluate_student()
# Out:
# Enter Roll Number: 8
# Enter Student Name: H
# Start page [1]: 1
# Question no. 1
# Grammar Score is 0.07727272727272727 out of 0.1
# Keyword Score is 0.4 out of 0.4
# Semantic Score is 0.5000000596046448 out of 0.5
# Q1: 0.98/1.0
# Question no. 2
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q2: 1.00/1.0
# Question no. 3
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q3: 0.83/1.0
# Question no. 4
# Grammar Score is 0.16363636363636364 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q4: 0.71/1.0
# Question no. 5
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q5: 0.58/1.0
# Question no. 6
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q6: 0.88/1.0
# Question no. 8
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q8: 0.92/1.0
# Question no. 10
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q10: 0.82/1.0
# Question no. 11
# Grammar Score is 0.19166666666666668 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q11: 0.99/1.0
# Question no. 12
# Grammar Score is 0.18095238095238098 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.06718119084835052 out of 0.3
# Q12: 0.25/1.0
# Question no. 14
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.04349543899297714 out of 0.3
# Q14: 0.22/1.0
# Question no. 16
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q16: 0.98/1.0
# Question no. 17
# Grammar Score is 0.19534883720930232 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.19864609837532043 out of 0.3
# Q17: 0.73/1.0
# Question no. 19
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q19: 0.98/1.0
# Question no. 21
# Grammar Score is 0.17272727272727273 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q21: 0.56/1.0
# Question no. 22
# Grammar Score is 0.18823529411764706 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q22: 0.82/1.0
# Question no. 23
# Grammar Score is 0.18888888888888888 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.04088756740093231 out of 0.3
# Q23: 0.23/1.0
# Question no. 25
# Grammar Score is 0.18947368421052635 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q25: 0.99/1.0
# Question no. 26
# Grammar Score is 0.19047619047619047 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q26: 0.82/1.0
# Question no. 27
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q27: 0.67/1.0
# Question no. 28
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q28: 0.82/1.0
# Question no. 29
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q29: 1.00/1.0
# Question no. 30
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q30: 0.73/1.0
# Question no. 31
# Grammar Score is 0.1625 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q31: 0.80/1.0
# Question no. 32
# Grammar Score is 0.16756756756756758 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.2737972497940063 out of 0.3
# Q32: 0.94/1.0
# Question no. 34
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q34: 0.49/1.0
# Question no. 35
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q35: 0.47/1.0
# Question no. 36
# Grammar Score is 0.18666666666666668 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999994635581967 out of 0.3
# Q36: 0.99/1.0
# Question no. 37
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.060489159822463986 out of 0.3
# Q37: 0.26/1.0
# Question no. 39
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.0775726854801178 out of 0.3
# Q39: 0.28/1.0
# Question no. 41
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q41: 0.66/1.0
# Question no. 42
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999992847442625 out of 0.3
# Q42: 0.82/1.0
# Question no. 43
# Grammar Score is 0.18823529411764706 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q43: 0.99/1.0
# Question no. 44
# Grammar Score is 0.15789473684210528 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q44: 0.62/1.0
# Question no. 45
# Grammar Score is 0.17894736842105263 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.05896121263504028 out of 0.3
# Q45: 0.24/1.0
# Question no. 49
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q49: 0.64/1.0
# Question no. 50
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q50: 0.82/1.0
# Question no. 51
# Grammar Score is 0.08461538461538462 out of 0.1
# Keyword Score is 0.2 out of 0.4
# Semantic Score is 0.4999999701976776 out of 0.5
# Q51: 0.78/1.0
# Question no. 52
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q52: 0.75/1.0
# Question no. 53
# Grammar Score is 0.08571428571428573 out of 0.1
# Keyword Score is 0.26666666666666666 out of 0.4
# Semantic Score is 0.4391735792160034 out of 0.5
# Q53: 0.79/1.0
# Question no. 55
# Grammar Score is 0.08333333333333334 out of 0.1
# Keyword Score is 0.26666666666666666 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q55: 0.85/1.0
# Question no. 56
# Grammar Score is 0.08000000000000002 out of 0.1
# Keyword Score is 0.26666666666666666 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q56: 0.85/1.0
# Question no. 57
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q57: 0.73/1.0
# Question no. 58
# Grammar Score is 0.15714285714285714 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q58: 0.96/1.0
# Question no. 59
# Grammar Score is 0.17391304347826086 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q59: 0.64/1.0
# Question no. 60
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q60: 0.65/1.0
# Question no. 61
# Grammar Score is 0.16842105263157894 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q61: 0.97/1.0
# Question no. 62
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.11523298323154449 out of 0.3
# Q62: 0.29/1.0
# Question no. 66
# Grammar Score is 0.1 out of 0.1
# Keyword Score is 0.13333333333333333 out of 0.4
# Semantic Score is 0.5000000596046448 out of 0.5
# Q66: 0.73/1.0
# Question no. 67
# Grammar Score is 0.09230769230769231 out of 0.1
# Keyword Score is 0.33333333333333337 out of 0.4
# Semantic Score is 0.4999999403953552 out of 0.5
# Q67: 0.93/1.0
# Question no. 68
# Grammar Score is 0.1625 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q68: 0.80/1.0
# Question no. 69
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q69: 0.65/1.0
# Question no. 70
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29999994635581967 out of 0.3
# Q70: 0.64/1.0
# Question no. 71
# Grammar Score is 0.18947368421052635 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q71: 0.74/1.0
# Question no. 72
# Grammar Score is 0.1375 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q72: 0.85/1.0
# Question no. 73
# Grammar Score is 0.16470588235294117 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q73: 0.88/1.0
# Question no. 74
# Grammar Score is 0.18181818181818182 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q74: 0.98/1.0
# Question no. 75
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q75: 0.73/1.0
# Question no. 76
# Grammar Score is 0.17894736842105263 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q76: 0.65/1.0
# Question no. 77
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.29999994635581967 out of 0.3
# Q77: 0.82/1.0
# Question no. 78
# Grammar Score is 0.17333333333333334 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q78: 0.72/1.0
# Question no. 79
# Grammar Score is 0.16470588235294117 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q79: 0.96/1.0
# Question no. 80
# Grammar Score is 0.15555555555555556 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q80: 0.96/1.0
# Question no. 81
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.4166666666666667 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q81: 0.89/1.0
# Question no. 82
# Grammar Score is 0.1473684210526316 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q82: 0.78/1.0
# Question no. 83
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q83: 0.99/1.0
# Question no. 84
# Grammar Score is 0.12857142857142856 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q84: 0.68/1.0
# Question no. 85
# Grammar Score is 0.13999999999999999 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.09995073974132537 out of 0.3
# Q85: 0.24/1.0
# Question no. 87
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q87: 0.75/1.0
# Question no. 88
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.07735780477523803 out of 0.3
# Q88: 0.28/1.0
# Question no. 91
# Grammar Score is 0.15714285714285714 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q91: 0.96/1.0
# Question no. 92
# Grammar Score is 0.1466666666666667 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q92: 0.53/1.0
# Question no. 93
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.10683254599571228 out of 0.3
# Q93: 0.27/1.0
# Question no. 95
# Grammar Score is 0.07692307692307693 out of 0.1
# Keyword Score is 0.13333333333333333 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q95: 0.71/1.0
# Question no. 96
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q96: 1.00/1.0
# Question no. 97
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q97: 0.67/1.0
# Question no. 98
# Grammar Score is 0.1466666666666667 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q98: 0.78/1.0
# Question no. 99
# Grammar Score is 0.18666666666666668 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q99: 0.99/1.0
# Question no. 100
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q100: 0.56/1.0
# Question no. 101
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q101: 0.99/1.0
# Question no. 102
# Grammar Score is 0.12307692307692308 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q102: 0.67/1.0
# Question no. 103
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.038446033000946046 out of 0.3
# Q103: 0.22/1.0
# Question no. 105
# Grammar Score is 0.168 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q105: 0.55/1.0
# Question no. 106
# Grammar Score is 0.19444444444444445 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.22233853340148926 out of 0.3
# Q106: 0.92/1.0
# Question no. 108
# Grammar Score is 0.19230769230769232 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q108: 0.99/1.0
# Question no. 109
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29803515672683717 out of 0.3
# Q109: 0.66/1.0
# Question no. 110
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29955210685729977 out of 0.3
# Q110: 1.00/1.0
# Question no. 111
# Grammar Score is 0.15 out of 0.15
# Keyword Score is 0.19999999999999998 out of 0.6
# Semantic Score is 0.25 out of 0.25
# Q111: 0.60/1.0
# Question no. 112
# Grammar Score is 0.17333333333333334 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.263820344209671 out of 0.3
# Q112: 0.60/1.0
# Question no. 114
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q114: 0.82/1.0
# Question no. 115
# Grammar Score is 0.18095238095238098 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q115: 0.98/1.0
# Question no. 116
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q116: 0.72/1.0
# Question no. 117
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q117: 0.72/1.0
# Question no. 118
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q118: 1.00/1.0
# Question no. 119
# Grammar Score is 0.17333333333333334 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q119: 0.64/1.0
# Question no. 120
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q120: 0.66/1.0
# Question no. 121
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q121: 1.00/1.0
# Question no. 122
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q122: 0.97/1.0
# Question no. 123
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q123: 0.98/1.0
# Question no. 124
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q124: 1.00/1.0
# Question no. 125
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q125: 0.99/1.0
# Question no. 126
# Grammar Score is 0.12307692307692308 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q126: 0.67/1.0
# Question no. 127
# Grammar Score is 0.18947368421052635 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q127: 0.82/1.0
# Question no. 128
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q128: 0.73/1.0
# Question no. 129
# Grammar Score is 0.168 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q129: 0.55/1.0
# Question no. 130
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q130: 1.00/1.0
# Question no. 131
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q131: 0.99/1.0
# Question no. 132
# Grammar Score is 0.19230769230769232 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q132: 0.99/1.0
# Question no. 133
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.08441530466079712 out of 0.3
# Q133: 0.28/1.0
# Question no. 135
# Grammar Score is 0.15 out of 0.15
# Keyword Score is 0.19999999999999998 out of 0.6
# Semantic Score is 0.25 out of 0.25
# Q135: 0.60/1.0
# Question no. 136
# Grammar Score is 0.15555555555555556 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q136: 0.62/1.0
# Question no. 137
# Grammar Score is 0.18461538461538463 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q137: 0.98/1.0
# Question no. 138
# Grammar Score is 0.19090909090909092 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q138: 0.82/1.0
# Question no. 139
# Grammar Score is 0.17500000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.01051824241876602 out of 0.3
# Q139: 0.19/1.0
# Question no. 141
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q141: 0.72/1.0
# Question no. 142
# Grammar Score is 0.18947368421052635 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.24487223625183105 out of 0.3
# Q142: 0.93/1.0
# Question no. 145
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q145: 1.00/1.0
# Question no. 146
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.29999998211860657 out of 0.3
# Q146: 0.97/1.0
# Question no. 147
# Grammar Score is 0.17647058823529413 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q147: 0.98/1.0
# Question no. 148
# Grammar Score is 0.18571428571428572 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.08044151365756988 out of 0.3
# Q148: 0.27/1.0
# Question no. 150
# Grammar Score is 0.12307692307692308 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q150: 0.67/1.0
# Question no. 151
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.20774792432785033 out of 0.3
# Q151: 0.55/1.0
# Question no. 153
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q153: 0.45/1.0
# Question no. 154
# Grammar Score is 0.12307692307692308 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q154: 0.42/1.0
# Question no. 155
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q155: 0.67/1.0
# Question no. 156
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q156: 0.46/1.0
# Question no. 157
# Grammar Score is 0.15714285714285714 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q157: 0.54/1.0
# Question no. 158
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q158: 0.64/1.0
# Question no. 159
# Grammar Score is 0.18181818181818182 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q159: 0.73/1.0
# Question no. 160
# Grammar Score is 0.1875 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q160: 0.57/1.0
# Question no. 161
# Grammar Score is 0.17777777777777778 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q161: 0.56/1.0
# Question no. 162
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q162: 0.47/1.0
# Question no. 163
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q163: 0.67/1.0
# Question no. 164
# Grammar Score is 0.08000000000000002 out of 0.1
# Keyword Score is 0.2 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q164: 0.78/1.0
# Question no. 165
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q165: 0.80/1.0
# Question no. 166
# Grammar Score is 0.15384615384615385 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q166: 0.45/1.0
# Question no. 167
# Grammar Score is 0.16470588235294117 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q167: 0.63/1.0
# Question no. 168
# Grammar Score is 0.08571428571428573 out of 0.1
# Keyword Score is 0.0 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q168: 0.59/1.0
# Question no. 169
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q169: 0.63/1.0
# Question no. 171
# Grammar Score is 0.19285714285714287 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.22769163250923155 out of 0.3
# Q171: 0.50/1.0
# Question no. 173
# Grammar Score is 0.16923076923076924 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q173: 0.72/1.0
# Question no. 174
# Grammar Score is 0.16363636363636364 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q174: 0.63/1.0
# Question no. 175
# Grammar Score is 0.09000000000000001 out of 0.1
# Keyword Score is 0.4 out of 0.4
# Semantic Score is 0.5 out of 0.5
# Q175: 0.99/1.0
# Question no. 176
# Grammar Score is 0.1466666666666667 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q176: 0.61/1.0
# Question no. 177
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q177: 0.54/1.0
# Question no. 178
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.25 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q178: 0.71/1.0
# Question no. 179
# Grammar Score is 0.18000000000000002 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.11490150690078735 out of 0.3
# Q179: 0.29/1.0
# Question no. 181
# Grammar Score is 0.1466666666666667 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.05618312805891037 out of 0.3
# Q181: 0.20/1.0
# Question no. 183
# Grammar Score is 0.1466666666666667 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.29999996423721315 out of 0.3
# Q183: 0.61/1.0
# Question no. 184
# Grammar Score is 0.14615384615384616 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.26926061511039734 out of 0.3
# Q184: 0.42/1.0
# Question no. 186
# Grammar Score is 0.07692307692307693 out of 0.1
# Keyword Score is 0.0 out of 0.4
# Semantic Score is 0.11546222120523453 out of 0.5
# Q186: 0.19/1.0
# Question no. 188
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q188: 0.63/1.0
# Question no. 189
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.5 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q189: 1.00/1.0
# Question no. 190
# Grammar Score is 0.18333333333333335 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q190: 0.57/1.0
# Question no. 191
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q191: 0.47/1.0
# Question no. 192
# Grammar Score is 0.16000000000000003 out of 0.2
# Keyword Score is 0.3333333333333333 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q192: 0.79/1.0
# Question no. 193
# Grammar Score is 0.17142857142857146 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q193: 0.55/1.0
# Question no. 194
# Grammar Score is 0.2 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q194: 0.67/1.0
# Question no. 195
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.16666666666666666 out of 0.5
# Semantic Score is 0.3 out of 0.3
# Q195: 0.63/1.0
# Question no. 196
# Grammar Score is 0.192 out of 0.2
# Keyword Score is 0.0 out of 0.5
# Semantic Score is 0.23546504974365234 out of 0.3
# Q196: 0.43/1.0
# Question no. 198
# Grammar Score is 0.15000000000000002 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000007152557373 out of 0.3
# Q198: 0.53/1.0
# Question no. 199
# Grammar Score is 0.16363636363636364 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q199: 0.55/1.0
# Question no. 200
# Grammar Score is 0.16666666666666669 out of 0.2
# Keyword Score is 0.08333333333333333 out of 0.5
# Semantic Score is 0.30000003576278683 out of 0.3
# Q200: 0.55/1.0
#
# Processed H (8). Total: 114.7523660228281/163 (70.40%)
#
# ✅ Evaluation Complete!
